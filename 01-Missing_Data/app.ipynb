# %%
import pandas as pd
from pathlib import Path

csvpath  = Path("./items.csv")

# %%
items_df = pd.read_csv(csvpath)

# %%
items_df.head()
# Out:
#    Item Number  Price   Quantity
# 0         2468    2.99       250
# 1         1357     NaN       300
# 2         9753    3.47       350

# %%
items_df
# Out:
#    Item Number  Price   Quantity
# 0         2468    2.99       250
# 1         1357     NaN       300
# 2         9753    3.47       350

# %%
items_df.isnull()
# Out:
#    Item Number  Price   Quantity
# 0        False   False     False
# 1        False    True     False
# 2        False   False     False

# %%
items_df.isnull().sum()
# Out:
# Item Number    0
# Price          1
# Quantity       0
# dtype: int64

# %%
import numpy as np

# %%
apple_df = pd.DataFrame({"AAPL": [72.27, np.nan, 74.39, np.nan, 75.94, 76.93,np.nan, 78.74, np.nan, 79.81, np.nan, 79.53, np.nan, 79.56, 79.49]})

apple_df
# Out:
#      AAPL
# 0   72.27
# 1     NaN
# 2   74.39
# 3     NaN
# 4   75.94
# 5   76.93
# 6     NaN
# 7   78.74
# 8     NaN
# 9   79.81
# 10    NaN
# 11  79.53
# 12    NaN
# 13  79.56
# 14  79.49

# %%
apple_df.isnull().sum()
# Out:
# AAPL    6
# dtype: int64

# %%
apple_df = pd.DataFrame({"AAPL": [72.27, np.nan, 74.39, np.nan, 75.94, 76.93,np.nan, 78.74, np.nan, 79.81, np.nan, 79.53, np.nan, 79.56, 79.49]})

apple_df
# Out:
#      AAPL
# 0   72.27
# 1     NaN
# 2   74.39
# 3     NaN
# 4   75.94
# 5   76.93
# 6     NaN
# 7   78.74
# 8     NaN
# 9   79.81
# 10    NaN
# 11  79.53
# 12    NaN
# 13  79.56
# 14  79.49

# %%
apple_df.isnull().sum()
# Out:
# AAPL    6
# dtype: int64

# %%
apple_df.dropna()
# Out:
#      AAPL
# 0   72.27
# 2   74.39
# 4   75.94
# 5   76.93
# 7   78.74
# 9   79.81
# 11  79.53
# 13  79.56
# 14  79.49

# %%
apple_df = pd.DataFrame({"AAPL": [72.27, np.nan, 74.39, np.nan, 75.94, 76.93,np.nan, 78.74, np.nan, 79.81, np.nan, 79.53, np.nan, 79.56, 79.49]})

apple_df
# Out:
#      AAPL
# 0   72.27
# 1     NaN
# 2   74.39
# 3     NaN
# 4   75.94
# 5   76.93
# 6     NaN
# 7   78.74
# 8     NaN
# 9   79.81
# 10    NaN
# 11  79.53
# 12    NaN
# 13  79.56
# 14  79.49

# %%
apple_df = apple_df.fillna(apple_df.mean())
apple_df
# Out:
#          AAPL
# 0   72.270000
# 1   77.406667
# 2   74.390000
# 3   77.406667
# 4   75.940000
# 5   76.930000
# 6   77.406667
# 7   78.740000
# 8   77.406667
# 9   79.810000
# 10  77.406667
# 11  79.530000
# 12  77.406667
# 13  79.560000
# 14  79.490000

# %%
aapl_returns = apple_df.fillna(0)

# %%
aapl_returns
# Out:
#          AAPL
# 0   72.270000
# 1   77.406667
# 2   74.390000
# 3   77.406667
# 4   75.940000
# 5   76.930000
# 6   77.406667
# 7   78.740000
# 8   77.406667
# 9   79.810000
# 10  77.406667
# 11  79.530000
# 12  77.406667
# 13  79.560000
# 14  79.490000

# %%
daily_returns = aapl_returns.fillna(aapl_returns.mean())

# %%
daily_returns
# Out:
#          AAPL
# 0   72.270000
# 1   77.406667
# 2   74.390000
# 3   77.406667
# 4   75.940000
# 5   76.930000
# 6   77.406667
# 7   78.740000
# 8   77.406667
# 9   79.810000
# 10  77.406667
# 11  79.530000
# 12  77.406667
# 13  79.560000
# 14  79.490000
